# %%
import os
import imp
import lib.lib as lib
imp.reload(lib)
# Out:
# <module 'lib.lib' from 'lib/lib.pyc'>

# %%
analyzer = lib.Analyze('../real_data_l1')

# %%
#analyzer.prepare(start_date="01.11.2014", finish_date="31.12.2014")
analyzer.prepare()

# %%
analyzer.summary()
# Out:
# {'all_expenses_sum': 19740.059999999998,
#  'count_expenses': 293,
#  'count_loaded_expenses': 293,
#  'count_tags': 41,
#  'expenses_sum': 19740.059999999998,
#  'finish_date': None,
#  'loaded_max_date': datetime.datetime(2014, 12, 31, 0, 0),
#  'loaded_min_date': datetime.datetime(2014, 11, 1, 0, 0),
#  'max_date': datetime.datetime(2014, 12, 31, 0, 0),
#  'min_date': datetime.datetime(2014, 11, 1, 0, 0),
#  'start_date': None}

# %%
analyzer.analyze_1()

# %%
analyzer.analyze_2()

# %%
tag_names = ['Clothes', 'Food', 'Gift', 'Cafe']
analyzer.analyze_3(tag_names)
