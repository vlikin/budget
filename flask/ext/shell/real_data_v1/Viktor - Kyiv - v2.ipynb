# %%
import os
import imp
import lib.lib as lib
imp.reload(lib)
# Out:
# <module 'lib.lib' from 'lib/lib.pyc'>

# %%
analyzer = lib.Analyze('./')

# %%
#analyzer.prepare(start_date="01.11.2014", finish_date="01.12.2014")
analyzer.prepare()

# %%
analyzer.summary()
# Out:
# {'all_expenses_sum': 10230.84,
#  'count_expenses': 150,
#  'count_loaded_expenses': 150,
#  'count_tags': 26,
#  'expenses_sum': 10230.84,
#  'finish_date': None,
#  'loaded_max_date': datetime.datetime(2014, 12, 17, 0, 0),
#  'loaded_min_date': datetime.datetime(2014, 10, 27, 0, 0),
#  'max_date': datetime.datetime(2014, 12, 17, 0, 0),
#  'min_date': datetime.datetime(2014, 10, 27, 0, 0),
#  'start_date': None}

# %%
analyzer.analyze_1()

# %%
analyzer.analyze_2()

# %%
tag_names = ['Meal', 'Hostel', 'Transport']
analyzer.analyze_3(tag_names)
